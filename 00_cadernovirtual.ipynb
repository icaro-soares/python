# %% [markdown]
# 1. Comandos Iniciais e Exibição (print)
# Para mostrar algo na tela, usamos a função print(). O conteúdo deve seguir regras específicas dependendo do tipo:
#
# * Textos (Strings): Devem estar entre aspas (simples ou duplas).
#
# * Números: São escritos sem aspas.
#
# * O sinal de +: * Com números: Realiza a soma aritmética. Ex: print(7 + 4) → 11.
#
# * Com strings: Realiza a concatenação (une os textos). Ex: print('7' + '4') → 74.

# %% [markdown]
# 2. Interatividade e Variáveis
# No Python, toda variável é um objeto e recebe valores através do sinal de igual (=).
#
# A função input()
#     Para permitir que o usuário interaja com o programa, usamos input().
#
# * Nota Importante: Por padrão, tudo o que o usuário digita no input() é lido pelo Python como uma string (texto).
#
#     Se você quiser realizar cálculos com o que o usuário digitou, precisa converter para um número usando int() ou float().

# %%
n1 = int(input('Digite um valor: '))

# %% [markdown]
# 3. Tipos Primitivos
# Os quatro tipos básicos fundamentais:
# * int: Números inteiros (sem vírgula). Ex.: .7, -4, 0, 1975
#
# * float: Números reais (com ponto flutuante). Ex.: 4.5, 0.076, -1.5
#
# * bool: Valores lógicos (Booleanos); True, False
#
# * str: Caracteres de texto (Strings). Ex.:'Olá', "Python"

# %% [markdown]
# 4. Operações Aritméticas e Precedência
# O Python segue uma ordem específica para resolver cálculos, muito similar à matemática:
#
# * Parênteses ()
#
# * Potência ** ou pow(x, y) (usando a função pow(x, y) a ordem de precedência é perdida)
#
# * Multiplicação, Divisão, Divisão Inteira e Módulo *, /, //, %
#
# * Adição e Subtração +, -
#
# Exemplos de Operadores "Diferentes":
#     // (Divisão inteira): Retorna apenas o número antes da vírgula.
#
#     % (Módulo): Retorna o resto da divisão.
#
#     ** (1/2): Forma de calcular a raiz quadrada. Ex: 81**(1/2) resulta em 9.0.

# %% [markdown]
# 5. Formatação de Saída (F-Strings)
# Existem formas modernas de exibir variáveis dentro de textos:
#
#     Método .format(): print('A soma vale {}'.format(s))
#
#     F-Strings (Mais prático): print(f'A soma vale {s}')
#
#     Truques de Formatação:
#     * {:>20}: Alinha à direita em 20 espaços.
#
#     * {:^20}: Centraliza em 20 espaços.
#
#     * {:=^20}: Centraliza colocando sinais de igual ao redor.
#
#     * end=' ': Impede que o print pule para a próxima linha.
#
#     * \n: Força a quebra de linha em qualquer lugar do texto.

# %% [markdown]
# 6. Módulos e Bibliotecas (import)
# O Python básico pode ser expandido com módulos específicos que não estão presentes em seu estado nativo, eles precisam ser exportados.
# Para isso usamos o comando <span style='color:red'>import</span>, e caso precisarmos apenas de uma função específica usaremos <span style='color:red'>from 'nome da biblioteca' import 'função'</span>
#
# * import math: Para cálculos avançados (ceil, floor, sqrt, factorial).
#
#     * bin, oct, hex = funções built-in do próprio compilador, não necessitam da biblioteca math
#
#     * ceil: arredonda valores tipo float para mais
#
#     * floor: arredonda valores tipo float para menos
#
#     * trunc: corta a parte após o ponto flutuante de um valor tipo float
#
#     * pow: forma de função da potência perde a ordem de precedencia
#
#     * sqrt: calcula a raiz quadrada de um número
#
#     * factorial: calcula o fatorial de um número
#
#     * hypot(ca, co): calcula a hipotenusa dos cateto adjacentes (ca) e cateto oposto (co)
#
#     * sin, cos, tan: calculam exatamente isso, seno, cosseno e tangente. Para conversões no Brasil os ângulos precisam primeiro ser convertidos para radianos usando outro módulo <span style='color:red'>radians</span>
#
# * from datetime import date:
#
#     <span style='color:red'>date.today().year</span> essa linha de código é usada para capturar o ano da máquina
#
# * import random: Para gerar números aleatórios ou escolher itens em listas
#
#     * random: gera números aleatórios entre 1 e 0
#
#     * randint(a, b): gera um número aleatório no intervalo de a e b
#
#     * randrange(a, b, c): gera um número entre a e b no intervalo de c, o b não é incluído na contagem.
#
#     * shuffle: embaralha os itens de uma lista
#
#     * choice: sorteia um item de uma lista
#
# * from time import sleep:
#
#     * Faz o programa esperar um certo tempo até executar a ação.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Dica de Ouro:</b> Lembre-se que o input() sempre lê o dado como texto (str)!
# </div>

# %% [markdown]
# ## Análise e Fatiamento de Texto
# O fatiamento permite pegar partes específicas de uma string usando índices. Lembre-se: o índice final não é incluído.
#
# ### Exemplos de Fatiamento:
# * `frase[9]`: Pega o caractere na posição 9.
# * `frase[9:21]`: Pega do 9 ao 20.
# * `frase[9:21:2]`: Pega do 9 ao 20, pulando de 2 em 2.
# * `frase[:5]`: Pega do 0 até o 4.
# * `frase[5:]`: Pega do 5 até o fim.

# %%
frase = 'Curso em Vídeo Python'

print(f'Comprimento: {len(frase)}') # Mostra o comprimento da string
print(f'Contar "o": {frase.count("o")}') # Conta o número de 'o'
print(f'Encontrar "deo": {frase.find("deo")}') # Verifica se o trecho se encontra na string
print(f'Existe "Curso"? {"Curso" in frase}') # Verifica se o trecho está presente

# Transformação
print(frase.replace('Python', 'Android')) # Troca 'Python' por 'Android', não altera a string origiral
print(frase.upper()) # Todas as letras maiúsculas
print(frase.lower()) # Todas as letras minúsculas
print(frase.capitalize()) # Só a primeira letra da frase
print(frase.title())      # Primeira letra de cada palavra
frase.rstrip() # Elimina os espaços em branco a direita da string
frase.lstrip() # Elimina os espaços em branco a esquerda da string
frase.strip() # Elimina os espaços em branco de ambos os lados da string
print(frase.split()) # Divide a string em pedaços menores levando em conta os espaços entre elas, recebe uma lista como retorno
frase.join('-') # Une as strings separadas anteriormente, recebe um argumento com o símbolo que será usado para fazer a união
print(frase.index('e')) # Retorna o índice da primeira aparição do elemento. Em caso de não existir retorna uma mensagem de erro.
print(frase.find('w')) # Faz quase a mesma coisa do .index, a diferença que quando não encontra o elemento retorna -1
frase.rindex('o') # Começa a procurar o elemento da direita para esquerda
frase.rfind('e') # Começa a procurar o elemento da direita para esquerda
print(frase.startswith('Curso')) # Verifica se a string começa com um termo, nos retornar True ou False
# Out:
# Comprimento: 21
# Contar "o": 3
# Encontrar "deo": 11
# Existe "Curso"? True
# Curso em Vídeo Android
# CURSO EM VÍDEO PYTHON
# curso em vídeo python
# Curso em vídeo python
# Curso Em Vídeo Python
# ['Curso', 'em', 'Vídeo', 'Python']
# 6
# -1
# True

# %% [markdown]
# ## Cores no Terminal (ANSI)
# Para colorir o terminal, usamos o padrão `\033[style;text;backm`.
#
# | Código | Significado |
# | :--- | :--- |
# | **Style** | 0 (None), 1 (Bold), 4 (Underline), 7 (Negative) |
# | **Text** | 30 (Branco) a 37 (Cinza) |
# | **Back** | 40 (Branco) a 47 (Cinza) |

# %%
# Exemplo Prático de Cores
cores = {
    'limpa': '\033[m',
    'azul': '\033[34m',
    'amarelo': '\033[33m',
    'pretoebranco': '\033[7;30m'
}

print(f"{cores['azul']}Olá, Mundo!{cores['limpa']}")
print(f"{cores['pretoebranco']}Fundo invertido!{cores['limpa']}")
# Out:
# Olá, Mundo!
# Fundo invertido!

# %% [markdown]
# ## Estrutura Simples vs. Composta
#
# * <b>Simples</b>: Você só diz o que fazer se a condição for verdadeira.
#
# * <b>Composta</b>: Você dá uma alternativa caso a condição seja falsa.

# %%
tempo_veículo = int(input('Quantos anos têm seu carro? '))

if tempo_veículo <= 3:
    print('Carro novo!')
else:
    print('Carro velho!')
print('--FIM--')
# Out:
# Carro velho!
# --FIM--

# %% [markdown]
# * <b>Condição simplificada</b>: Podemos simplificar essas linhas de código em apenas três linhas

# %%
tempo = int(input('Quantos anos têm seu carro? '))

status = 'Carro novo' if tempo <=3 else 'Carro velho'

print(status)
# Out:
# Carro velho

# %% [markdown]
# * <b>Mais condições</b>: Mas e se tivermos mais de duas opções? Nós usaremos o uso da palavra <b>elif</b>

# %%
idade = int(input('Qual sua idade? '))

if idade < 15:
    print('Criança')
elif 15<= idade < 18:
    print('Adolescente')
elif 18 <= idade < 30:
    print('Adulto')
elif 30 <= idade < 60:
    print('Maduro(a)')
else:
    print('Idoso(a)')
# Out:
# Idoso(a)

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Dica de ouro</b>: Podemos ter quanto <b>elif</b> precisarem, mas <b>if</b> e <b>else</b> podemos ter apenas um de cada.
# </div>

# %% [markdown]
# ## Estruturas de Controlo: Condições Aninhadas
#
# Enquanto uma condição composta tem apenas dois caminhos (if e else), as condições aninhadas permitem criar várias opções intermédias utilizando o comando elif (abreviação de else if).
#
# ## Estrutura Lógica:
#
#    * if: A primeira condição (obrigatória).
#
#    * elif: Condições intermédias (opcional, pode haver várias).
#
#    * else: O caminho final se nenhuma das anteriores for verdadeira (opcional).

# %%
nome = str(input('Qual é o teu nome? '))

if nome == 'Gustavo':
    print('Que nome bonito!')
elif nome == 'Pedro' or nome == 'Maria' or nome == 'Paulo':
    print('O teu nome é bem popular no Brasil.')
elif nome in 'Ana Cláudia Jéssica Juliana':
    print('Belo nome feminino!')
else:
    print('O teu nome é bem normal.')

print(f'Tenha um bom dia, {nome}!')
# Out:
# O teu nome é bem normal.
# Tenha um bom dia, Ícaro
# !

# %% [markdown]
# <div class="alert alert-block alert-info">Conversão de Bases (ex037): Uso de bin(), oct() e hex()</div>
